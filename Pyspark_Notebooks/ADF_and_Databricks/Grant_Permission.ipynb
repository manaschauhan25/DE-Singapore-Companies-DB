# %% [markdown]
# # Grant PERMISSION TO ADF FOR SILVER CATALOG

# %%
# %sql
GRANT USE CATALOG ON CATALOG silver TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  silver.clean TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   silver.clean.stocks TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG silver TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  silver.clean TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   silver.clean.acra TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG silver TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  silver.clean TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   silver.clean.companies_sg TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG silver TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  silver.clean TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   silver.clean.recordowl TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG silver TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  silver.clean TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT  ON TABLE   silver.clean.scrapped_wesbites TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG silver TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  silver.unified TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   silver.unified.unified_companies TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION staging TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %% [markdown]
# # GRANT PERMISSION AT GOLD CATALOG

# %%
# %sql
GRANT USE CATALOG ON CATALOG gold TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  gold.final TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   gold.final.llm_enriched_companies TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG gold TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT USE SCHEMA  ON SCHEMA  gold.final TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
GRANT SELECT ON TABLE   gold.final.master_companies TO `af2fc3a8-9205-41f5-8c67-69b66b155b45`;
