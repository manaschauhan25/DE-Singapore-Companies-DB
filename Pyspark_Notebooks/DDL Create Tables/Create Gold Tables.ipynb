# %%
# %sql
CREATE TABLE IF NOT EXISTS gold.final.master_companies (
    uen STRING,
    company_name STRING,
    website STRING,
    hq_country STRING,
    no_of_locations_in_singapore INT,
    linkedin STRING,
    facebook STRING,
    instagram STRING,
    industry STRING,
    number_of_employees INT,
    company_size STRING,
    is_it_delisted BOOLEAN,
    stock_exchange_code STRING,
    revenue DOUBLE,
    founding_year INT,
    products_offered STRING,
    services_offered STRING,
    keywords STRING,
    created_at TIMESTAMP,
    updated_at TIMESTAMP
)
USING DELTA
LOCATION 'abfss://gold@singaporecomadls.dfs.core.windows.net/final_gold_master';
